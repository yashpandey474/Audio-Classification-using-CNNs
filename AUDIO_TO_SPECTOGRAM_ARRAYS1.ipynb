# %%
import os
import numpy as np
import librosa
from google.colab import drive
import matplotlib.pyplot as plt
from PIL import Image
import cv2
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# HYPERPARAMETERS
duration_seconds = 4
sample_rate = 44100
hyper_params = {
    'duration': duration_seconds*sample_rate,
     'n_mels': 128,
    'hop_length': 512,
    'n_fft': 2048,
    'fmin': 20,
    'fmax': sample_rate//2
}

# %%
def audio_preprocess(file_path):
    waveform, sample_rate = librosa.load(file_path, sr=44100)

    #normalising the waveform since each audio file has the amplitude values in different ranges
    waveform = waveform / np.max(np.abs(waveform))

    #keeping values greater than threshold
    waveform, index = librosa.effects.trim(waveform, top_db=60)

    # keeping values greater than threshold = 0.001
    wav = np.abs(waveform)
    mask = wav > 0.001     # 0.001 is equivalent to a 60db threshold
    waveform = waveform[mask]

    # pad to a length of 4s
    if len(waveform) > hyper_params['duration']:
        waveform = waveform[:hyper_params['duration']]
    else:
        padding = hyper_params['duration'] - len(waveform)
        offset = padding // 2
        waveform = np.pad(waveform, (offset, hyper_params['duration'] - len(waveform) - offset), 'constant')

    return waveform, sample_rate

def compute_mel_spectrogram(audio_file_path, n_fft=2048, hop_length=512, n_mels=128):
    # Load the audio file
    y, sr = audio_preprocess(audio_file_path)

    # Compute the mel spectrogram
    mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    mel_spec_db = mel_spec_db.astype(np.float32)

    return mel_spec_db


def mono_to_color2(X):
    # Convert single-channel image to three channels
    color_img = cv2.cvtColor(X, cv2.COLOR_GRAY2BGR)

    # Normalize pixel values to the range [0, 255]
    normalized_img = cv2.normalize(color_img, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

    return normalized_img

def mono_to_color(X, mean=None, std=None, norm_max=None, norm_min=None, eps=1e-6):
    X = np.stack([X, X, X], axis=-1)
    mean = mean or X.mean()
    X = X - mean
    std = std or X.std()
    Xstd = X / (std + eps)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = norm_max or _max
    norm_min = norm_min or _min


    if (_max - _min) > eps:
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        V = V.astype(np.uint8)
    else:
        V = np.zeros_like(Xstd, dtype=np.uint8)
    return V

# %%
def save_mel_spectrogram_as_image(mel_spec, output_image_path):
    # Plot the mel spectrogram without axes and color bar
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mel_spec, hop_length=512, x_axis=None, y_axis=None)
    plt.axis('off')  # Turn off axes

    # Save the mel spectrogram as an image without padding
    plt.savefig(output_image_path, bbox_inches='tight', pad_inches=0, transparent=True)
    plt.close()

# %%
def process_label_folder(label_directory, output_label_directory):
    # Loop through each audio file in the label directory
    for audio_file in os.listdir(label_directory):
        audio_file_path = os.path.join(label_directory, audio_file)

        try:
            # Compute mel spectrogram
            mel_spec = compute_mel_spectrogram(audio_file_path)

            # Convert to 3 channels [Better for inputting to CNN model]
            mel_spec = mono_to_color2(mel_spec)

            print(mel_spec.shape)

            output_npz_path = os.path.join(output_label_directory, os.path.splitext(audio_file)[0] + '.npz')
            np.savez(output_npz_path, mel_spec=mel_spec)

            print(f'Saved mel spectrogram array: {output_npz_path}')
        except Exception as e:
            print(f'Error processing {audio_file}: {str(e)}')
            continue

# %%
def process_audio_dataset(root_directory, output_directory):
    # Loop through 'train' and 'val' subfolders
    for subfolder in ['train', 'val']:
        subfolder_directory = os.path.join(root_directory, subfolder)

        # Loop through each label folder in the 'train' or 'val' subfolder
        for label in os.listdir(subfolder_directory):
        # for label in ['Laughter', 'Shatter', 'Snare_drum', 'Splash_and_splatter', 'siren']:
            label_directory = os.path.join(subfolder_directory, label)

            # Create a corresponding output subfolder for the label
            output_label_directory = os.path.join(output_directory, subfolder, label)
            os.makedirs(output_label_directory, exist_ok=True)

            # Process audio files in label folder
            process_label_folder(label_directory, output_label_directory)

# %%
def main():
    # Define the root directory containing 'audio_dataset'
    root_directory = '/content/drive/My Drive/audio_dataset/audio_dataset'

    # Define the directory where mel spectrogram images will be saved
    output_directory = '/content/drive/My Drive/DLproject-Numpy/'

    # Process the audio dataset
    process_audio_dataset(root_directory, output_directory)


if __name__ == "__main__":
    main()
# Out:
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_1.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_10.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_100.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_101.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_102.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_103.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_104.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_105.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_106.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_107.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_108.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_109.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_11.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_110.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_111.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_112.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_113.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_114.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_115.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_116.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_117.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_118.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_119.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_12.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_120.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_121.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_122.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_123.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_124.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_125.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_126.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_127.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_128.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_129.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_13.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_130.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_131.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_132.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_133.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_134.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_135.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_136.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_137.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_138.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_139.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_14.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_140.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_141.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_142.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_143.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_144.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_145.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_146.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_147.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_148.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_149.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_15.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_150.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_151.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_152.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_153.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_154.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_155.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_156.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_157.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_158.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_159.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_16.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_160.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_161.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_162.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_163.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_164.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_165.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_166.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_167.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_168.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_169.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_17.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_170.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_171.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_172.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_173.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_174.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_175.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_176.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_177.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_178.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_179.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_18.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_180.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_181.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_182.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_183.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_184.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_185.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_186.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_187.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_188.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_189.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_19.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_190.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_191.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_192.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_193.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_194.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_195.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_196.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_197.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_198.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_199.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_2.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_20.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_200.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_201.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_202.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_203.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_204.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_205.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_206.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_207.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_208.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_209.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_21.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_210.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_211.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_212.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_213.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_214.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_215.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_216.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_217.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_218.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_219.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_22.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_220.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_221.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_222.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_223.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_224.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_225.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_226.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_227.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_228.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_229.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_23.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_230.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_231.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_232.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_233.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_234.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_235.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_236.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_237.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_238.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_239.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_24.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_240.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_241.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_242.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_243.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_244.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_245.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_246.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_247.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_248.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_249.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_25.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_250.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_251.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_252.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_253.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_254.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_255.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_256.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_257.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_258.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_259.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_26.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_260.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_261.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_262.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_263.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_264.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_265.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_266.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_267.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_268.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_269.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_27.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_270.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_271.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_272.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_273.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_274.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_275.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_276.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_277.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_278.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_279.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_28.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_280.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_281.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_282.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_283.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_284.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_285.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_286.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_287.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_288.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_289.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_29.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_290.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_291.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_3.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_30.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_31.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_32.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_33.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_34.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_35.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_36.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_37.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_38.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_39.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_4.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_40.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_41.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_42.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_43.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_44.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_45.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_46.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_47.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_48.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_49.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_5.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_50.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_51.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_52.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_53.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_54.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_55.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_56.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_57.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_58.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_59.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_6.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_60.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_61.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_62.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_63.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_64.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_65.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_66.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_67.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_68.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_69.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_7.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_70.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_71.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_72.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_73.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_74.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_75.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_76.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_77.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_78.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_79.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_8.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_80.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_81.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_82.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_83.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_84.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_85.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_86.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_87.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_88.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_89.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_9.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_90.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_91.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_92.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_93.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_94.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_95.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_96.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_97.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_98.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Fart/Fart_99.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_1.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_10.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_100.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_101.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_102.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_103.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_104.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_105.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_106.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_107.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_108.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_109.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_11.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_110.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_111.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_112.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_113.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_114.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_115.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_116.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_117.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_118.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_119.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_12.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_120.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_121.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_122.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_123.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_124.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_125.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_126.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_127.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_128.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_129.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_13.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_130.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_131.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_132.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_133.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_134.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_135.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_136.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_137.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_138.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_139.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_14.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_140.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_141.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_142.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_143.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_144.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_145.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_146.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_147.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_148.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_149.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_15.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_150.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_151.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_152.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_153.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_154.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_155.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_156.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_157.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_158.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_159.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_16.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_160.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_161.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_162.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_163.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_164.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_165.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_166.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_167.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_168.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_169.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_17.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_170.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_171.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_172.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_173.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_174.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_175.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_176.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_177.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_178.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_179.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_18.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_180.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_181.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_182.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_183.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_184.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_185.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_186.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_187.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_188.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_189.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_19.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_190.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_191.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_192.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_193.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_194.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_195.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_196.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_197.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_198.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_199.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_2.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_20.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_200.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_201.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_202.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_203.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_204.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_205.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_206.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_207.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_208.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_209.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_21.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_210.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_211.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_212.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_213.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_214.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_215.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_216.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_217.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_218.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_219.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_22.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_220.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_221.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_222.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_223.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_224.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_225.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_226.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_227.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_228.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_229.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_23.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_230.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_231.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_232.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_233.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_234.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_235.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/Guitar/Guitar_236.npz
# ...
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_143.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_144.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_145.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_146.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_147.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_148.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_149.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_15.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_150.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_151.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_152.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_153.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_154.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_155.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_156.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_157.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_158.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_159.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_16.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_160.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_161.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_162.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_163.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_164.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_165.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_166.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_167.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_168.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_169.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_17.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_170.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_171.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_172.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_173.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_174.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_175.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_176.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_177.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_178.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_179.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_18.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_180.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_181.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_182.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_183.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_184.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_185.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_186.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_187.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_188.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_189.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_19.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_190.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_191.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_192.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_193.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_194.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_195.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_196.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_197.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_198.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_199.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_2.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_20.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_200.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_201.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_202.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_203.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_204.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_205.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_206.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_207.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_208.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_209.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_21.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_210.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_211.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_212.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_213.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_214.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_215.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_216.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_217.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_218.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_219.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_22.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_220.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_221.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_222.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_223.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_224.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_225.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_226.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_227.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_228.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_229.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_23.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_230.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_231.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_232.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_233.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_234.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_235.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_236.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_237.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_238.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_239.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_24.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_240.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_241.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_242.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_243.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_244.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_245.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_246.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_247.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_248.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_249.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_25.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_250.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_251.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_252.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_253.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_254.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_255.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_256.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_257.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_258.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_259.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_26.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_260.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_261.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_262.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_263.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_264.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_265.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_266.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_267.npz
# (128, 345, 3)
# Saved mel spectrogram array: /content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_268.npz

# %%
data_dir = '/content/drive/My Drive/DLproject/train'
classes1 = os.listdir(data_dir)

# %%
def load_and_display_npz(npz_file_path):
    # Load the npz file
    data = np.load(npz_file_path)

    # Extract the mel spectrogram array
    mel_spec = data['mel_spec']

    # mel_spec = Image.fromarray(data['mel_spec'], mode='RGB')
    image = cv2.cvtColor(mel_spec, cv2.COLOR_RGB2BGR)  # Assuming RGB format, adjust accordingly

    # Convert the image back to a NumPy array
    arr_back = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert back to RGB format

    # print(type(image))
    # Display the mel spectrogram
    plt.figure(figsize=(10, 4))
    plt.imshow(image)
    plt.title('Mel Spectrogram')
    plt.xlabel('Time')
    plt.ylabel('Frequency')
    plt.colorbar(label='Amplitude (dB)')
    plt.show()

    return arr_back

# %%
# Example usage
npz_file_path = '/content/drive/My Drive/DLproject-Numpy/augmented_spectograms/car_horn/original_car_horn_1.npz.npz'
mel_spec = load_and_display_npz(npz_file_path)

# %%
npz_file_path = '/content/drive/My Drive/DLproject-Numpy/train/car_horn/car_horn_5.npz'
data = np.load(npz_file_path)
# Extract the mel spectrogram array
mel_spec = data['mel_spec']


mel_spec.shape
# Out:
# (128, 345, 3)

# %%
type(mel_spec)
# Out:
# numpy.ndarray

# %%
# Example usage
npz_file_path = '/content/drive/My Drive/DLproject-Numpy/train/Laughter/Laughter_120.npz'
mel_spec = load_and_display_npz(npz_file_path)

# %%
mel_spec.shape
# Out:
# (128, 224)

# %%
mel_spec_normalized = (mel_spec - mel_spec.min()) / (mel_spec.max() - mel_spec.min())

# Expand dimensions to make it a 3D image (height, width, channels)
mel_spec_rgb = np.stack((mel_spec_normalized,) * 3, axis=-1)

# %%
mel_spec_rgb = mono_to_color2(mel_spec)

# %%
plt.figure(figsize=(10, 4))
plt.imshow(mel_spec_rgb)
plt.title('Mel Spectrogram')
plt.axis('off')  # Remove axis ticks and labels
plt.show()

# %%
mel_spec_rgb.shape
# Out:
# (128, 224, 3)

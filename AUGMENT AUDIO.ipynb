# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
import numpy as np
import librosa
import soundfile as sf
from pydub import AudioSegment
from pydub.effects import strip_silence

def apply_audio_augmentation(input_path, output_path, augmentation_type):
    # Load the audio file
    audio, sample_rate = librosa.load(input_path, sr=None)

    if augmentation_type == "noise_injection":
        # Add white noise
        noise_factor = 0.005
        white_noise = np.random.randn(len(audio)) * noise_factor
        augmented_audio = audio + white_noise
    elif augmentation_type == "shifting_time":
        # Shift the audio in time
        shift_factor = 0.1  # Fraction of the total length to shift
        shift_samples = int(len(audio) * shift_factor)
        augmented_audio = np.roll(audio, shift_samples)
    elif augmentation_type == "changing_speed":
        # Change the speed of the audio
        speed_factor = 0.9  # Change speed by 10%
        augmented_audio = librosa.effects.time_stretch(audio, rate=speed_factor)
    elif augmentation_type == "changing_pitch":
        # Change the pitch of the audio
        pitch_factor = 1.2  # Increase pitch by 20%
        augmented_audio = librosa.effects.pitch_shift(audio, sr=sample_rate, n_steps=pitch_factor)
    else:
        raise ValueError("Invalid augmentation type. Choose from: noise_injection, shifting_time, changing_speed, changing_pitch")

    # Ensure audio is in 16-bit format before saving
    augmented_audio_16bit = (augmented_audio * np.iinfo(np.int16).max).astype(np.int16)

    # Save the augmented audio
    sf.write(output_path, augmented_audio_16bit, sample_rate)

#trial use case, upload whatever audio file, download untitled to see what has been changed
#apply_audio_augmentation('/content/car_horn_5.wav','/content/untitled.wav',"changing_speed")

# %%
import os
import random

# Define the function to apply audio augmentation
def apply_audio_augmentation(input_path, output_path, augmentation_type):
    # Load the audio file
    audio, sample_rate = librosa.load(input_path, sr=None)

    if augmentation_type == "noise_injection":
        # Add white noise
        noise_factor = 0.005
        white_noise = np.random.randn(len(audio)) * noise_factor
        augmented_audio = audio + white_noise
    elif augmentation_type == "shifting_time":
        # Shift the audio in time
        shift_factor = 0.1  # Fraction of the total length to shift
        shift_samples = int(len(audio) * shift_factor)
        augmented_audio = np.roll(audio, shift_samples)
    elif augmentation_type == "changing_speed":
        # Change the speed of the audio
        speed_factor = 0.9  # Change speed by 10%
        augmented_audio = librosa.effects.time_stretch(audio, rate=speed_factor)
    elif augmentation_type == "changing_pitch":
        # Change the pitch of the audio
        pitch_factor = 1.2  # Increase pitch by 20%
        augmented_audio = librosa.effects.pitch_shift(audio, sr=sample_rate, n_steps=pitch_factor)
    else:
        raise ValueError("Invalid augmentation type. Choose from: noise_injection, shifting_time, changing_speed, changing_pitch")

    # Ensure audio is in 16-bit format before saving
    augmented_audio_16bit = (augmented_audio * np.iinfo(np.int16).max).astype(np.int16)

    # Save the augmented audio
    sf.write(output_path, augmented_audio_16bit, sample_rate)


# Define the function to process the audio dataset
def process_audio_dataset(input_directory, output_directory):
    for root, dirs, files in os.walk(input_directory):
        for dir_name in dirs:
            folder_path = os.path.join(root, dir_name)
            file_count = len([file for file in os.listdir(folder_path) if file.endswith(".wav")])
            if file_count < 640:  # Check if folder contains less than 640 .wav files
                # Create a new folder for augmented data
                augmented_folder_path = os.path.join(root, f"augmented_{dir_name}")
                os.makedirs(augmented_folder_path, exist_ok=True)

                # Augment the audio files
                files_to_augment = random.sample(os.listdir(folder_path), 640 - file_count)
                for file_name in files_to_augment:
                    input_file_path = os.path.join(folder_path, file_name)
                    output_file_name = f"aug_{file_name}"
                    output_file_path = os.path.join(augmented_folder_path, output_file_name)
                    # Randomly choose augmentation type
                    augmentation_type = random.choice(["noise_injection", "shifting_time", "changing_speed", "changing_pitch"])
                    apply_audio_augmentation(input_file_path, output_file_path, augmentation_type)


# Define input and output directories
input_directory_train = '/content/drive/My Drive/DLproject/audio dataset/audio_dataset/train'
input_directory_val = '/content/drive/My Drive/DLproject/audio dataset/audio_dataset/val'

# Process the audio dataset in the train folder
process_audio_dataset(input_directory_train, input_directory_train)

# Process the audio dataset in the val folder
process_audio_dataset(input_directory_val, input_directory_val)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import random
import librosa
import numpy as np
import soundfile as sf

def augment_audio_folder(input_folder, output_folder):
    """
    Augments audio files in the input directory and saves them to the output directory.
    """
    # Ensure the output directory exists
    os.makedirs(output_folder, exist_ok=True)

    # Loop through each folder and subfolder in the input directory
    for root, dirs, files in os.walk(input_folder):
        # Determine the relative path from the input folder to the current folder
        relative_path = os.path.relpath(root, input_folder)
        output_subfolder = os.path.join(output_folder, relative_path)

        # Ensure the corresponding output subfolder exists
        os.makedirs(output_subfolder, exist_ok=True)

        print("Augmenting files in folder:", relative_path)

        # Loop through each file in the current folder
        for file_name in files:
            # Check if the file is a WAV file
            if file_name.endswith(".wav"):
                # Load the audio file
                audio_path = os.path.join(root, file_name)
                y, sr = librosa.load(audio_path, sr=None)

                # Choose a random augmentation type
                augmentation_type = random.choice(["time_shift", "speed_change", "pitch_shift"])

                # Apply the chosen augmentation
                if augmentation_type == "time_shift":
                    augmented_audio = np.roll(y, 3000)
                elif augmentation_type == "speed_change":
                    rate = random.uniform(0.7, 1.3)
                    augmented_audio = librosa.effects.time_stretch(y, rate=rate)
                elif augmentation_type == "pitch_shift":
                    n_steps = random.uniform(-2, 2)  # Number of semitones to shift the pitch
                    augmented_audio = librosa.effects.pitch_shift(y, n_steps=random.uniform(-2,2),sr=sr)

                # Save the augmented audio to the output directory
                output_file_name = "aug_" + file_name
                output_audio_path = os.path.join(output_subfolder, output_file_name)
                sf.write(output_audio_path, augmented_audio, sr)

                print(f"Augmented file saved: {output_audio_path}")

# Example usage:
input_folder = "/content/drive/My Drive/DLproject/audio dataset/audio_dataset/train"
output_folder = "/content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented"

augment_audio_folder(input_folder, output_folder)
# Out:
# Augmenting files in folder: .
# Augmenting files in folder: car_horn
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_110.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_122.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_106.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_102.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_115.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_127.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_1.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_117.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_101.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_104.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_120.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_125.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_116.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_119.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_11.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_111.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_109.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_126.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_103.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_112.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_128.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_121.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_123.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_100.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_107.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_105.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_10.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_12.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_118.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_124.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_113.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_129.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_108.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_114.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_152.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_16.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_130.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_139.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_145.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_147.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_154.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_149.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_159.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_153.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_156.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_15.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_162.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_134.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_160.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_137.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_135.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_155.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_132.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_14.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_144.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_131.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_142.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_138.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_146.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_163.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_158.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_140.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_13.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_148.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_161.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_141.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_136.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_143.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_157.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_150.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_151.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_133.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_169.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_170.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_179.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_188.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_195.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_178.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_185.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_186.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_196.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_181.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_174.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_194.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_164.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_189.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_197.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_192.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_180.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_171.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_191.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_183.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_168.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_184.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_175.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_177.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_176.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_182.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_187.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_165.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_19.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_193.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_17.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_166.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_167.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_173.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_18.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_190.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_172.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_227.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_204.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_224.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_203.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_214.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_208.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_221.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_211.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_22.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_202.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_228.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_206.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_205.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_216.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_226.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_2.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_207.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_200.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_201.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_210.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_219.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_213.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_215.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_222.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_23.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_225.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_217.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_212.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_199.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_223.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_198.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_21.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_20.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_229.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_209.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_218.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_220.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_235.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_259.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_241.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_254.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_25.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_257.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_236.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_232.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_242.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_248.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_26.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_246.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_261.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_233.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_263.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_255.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_251.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_250.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_238.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_244.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_234.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_245.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_253.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_237.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_258.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_24.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_252.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_247.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_239.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_231.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_249.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_260.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_240.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_256.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_262.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_230.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_243.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_273.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_291.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_279.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_294.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_276.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_264.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_267.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_27.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_284.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_272.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_286.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_271.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_290.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_28.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_297.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_285.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_283.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_292.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_295.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_280.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_275.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_268.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_266.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_288.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_287.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_289.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_277.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_281.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_274.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_296.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_29.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_270.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_269.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_265.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_278.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_293.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_282.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_326.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_318.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_321.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_327.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_310.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_302.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_30.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_323.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_299.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_329.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_304.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_315.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_300.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_324.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_308.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_317.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_303.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_305.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_311.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_316.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_322.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_319.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_3.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_314.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_307.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_312.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_298.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_31.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_325.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_313.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_320.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_309.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_328.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_32.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_301.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_306.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_50.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_339.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_331.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_36.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_340.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_40.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_39.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_34.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_37.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_337.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_5.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_38.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_336.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_341.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_41.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_334.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_42.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_47.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_333.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_44.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_342.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_48.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_335.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_33.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_35.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_4.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_45.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_49.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_338.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_43.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_330.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_343.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_344.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_51.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_332.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_46.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_70.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_76.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_84.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_69.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_63.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_60.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_65.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_67.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_57.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_56.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_55.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_73.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_61.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_75.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_71.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_7.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_54.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_72.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_64.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_62.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_6.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_79.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_77.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_53.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_52.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_81.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_59.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_74.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_83.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_82.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_78.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_8.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_66.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_68.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_80.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_58.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_86.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_96.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_87.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_92.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_95.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_97.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_99.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_9.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_88.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_98.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_89.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_93.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_91.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_85.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_90.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/car_horn/aug_car_horn_94.wav
# Augmenting files in folder: dog_barking
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_104.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_103.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_11.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_10.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_112.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_109.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_111.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_100.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_113.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_105.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_1.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_101.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_115.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_102.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_114.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_110.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_106.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_107.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_108.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_119.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_138.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_143.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_125.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/dog_barking/aug_dog_barking_131.wav
# ...
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_473.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_472.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_469.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_481.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_491.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_471.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_492.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_49.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_494.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_487.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_48.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_488.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_499.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_512.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_50.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_527.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_513.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_502.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_510.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_51.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_52.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_516.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_509.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_517.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_515.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_528.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_521.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_518.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_514.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_504.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_520.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_526.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_522.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_519.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_5.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_511.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_505.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_506.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_500.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_501.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_525.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_508.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_523.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_503.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_507.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_524.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_54.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_53.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_541.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_532.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_546.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_533.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_536.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_548.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_552.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_55.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_542.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_555.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_530.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_537.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_556.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_551.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_558.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_547.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_553.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_544.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_539.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_535.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_554.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_538.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_529.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_557.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_559.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_545.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_531.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_534.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_540.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_549.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_543.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_550.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_82.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_79.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_84.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_63.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_66.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_73.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_56.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_83.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_6.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_69.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_75.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_78.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_77.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_58.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_71.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_57.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_64.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_560.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_62.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_60.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_76.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_59.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_70.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_74.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_61.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_7.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_8.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_65.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_80.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_68.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_81.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_67.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_72.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_99.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_92.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_96.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_90.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_98.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_97.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_95.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_91.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_86.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_93.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_88.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_9.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_87.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_85.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_89.wav
# Augmented file saved: /content/drive/My Drive/DLproject/audio dataset/audio_dataset/train_augmented/siren/aug_siren_94.wav
# Augmenting files in folder: augmented_car_horn
